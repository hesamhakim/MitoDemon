# %%
import sys
sys.path.append('../src')
import numpy as np
import pandas as pd
from vcf_processor import VCFProcessor
from variant_clustering import VariantClusterer
from deconvolution_models import DeconvolutionModels
import pyro
import pyro.distributions as dist  # For Dirichlet distribution
from pyro.infer import SVI, Trace_ELBO, Predictive  # NEW: For variational inference and sampling
from pyro.optim import Adam  # NEW: For optimizer (was implicit)
import torch
from pathlib import Path
import json
from scipy.optimize import minimize

# %%
# List of VCF paths (from context)
vcf_paths = [
    "../../../data/vault_pipeline_output/SRR12676841_output/snp/all_snp_from_perfect_umi.vcf",
    "../../../data/vault_pipeline_output/SRR12676842_output/snp/all_snp_from_perfect_umi.vcf",
    "../../../data/vault_pipeline_output/SRR12676843_output/snp/all_snp_from_perfect_umi.vcf",
    "../../../data/vault_pipeline_output/SRR12676844_output/snp/all_snp_from_perfect_umi.vcf",
    "../../../data/vault_pipeline_output/SRR12676845_output/snp/all_snp_from_perfect_umi.vcf",
    "../../../data/vault_pipeline_output/SRR12676846_output/snp/all_snp_from_perfect_umi.vcf"
]
# Extract cluster proportions from each VCF
historical_proportions = []
for vcf_path in vcf_paths:
    processor = VCFProcessor(vcf_path)
    variants_df = processor.read_vcf()
    filtered_variants = processor.apply_filters(include_indels=True, min_vaf=0.15)
    variant_matrix = processor.get_variant_matrix(continuous=True, include_indels=True)
    clusterer = VariantClusterer(method='spectral', n_clusters=20)
    _, cluster_labels = clusterer.fit_predict(variant_matrix)
    # Ignore -1 labels (noise/zeros)
    valid_labels = cluster_labels[cluster_labels >= 0]
    if len(np.unique(valid_labels)) < 2:
        print(f"Skipping {vcf_path}: insufficient clusters after filtering.")
        continue
    props = np.bincount(valid_labels, minlength=20) / len(valid_labels)
    historical_proportions.append(props)
historical_proportions = np.array(historical_proportions)
# Check if we have data
if len(historical_proportions) == 0:
    raise ValueError("No valid proportions extracted from any VCF. Check data or filtering.")
# Normalize proportions to ensure they sum to 1 (add epsilon for stability)
historical_proportions = historical_proportions / (historical_proportions.sum(axis=1, keepdims=True) + 1e-10)
# Fit Dirichlet prior (concentration params favor sparsity)
def dirichlet_neg_log_lik(alpha, data):
    alpha_t = torch.tensor(alpha)
    data_t = torch.tensor(data)
    return -torch.sum(dist.Dirichlet(alpha_t).log_prob(data_t))  # Use torch.sum for tensor compatibility
res = minimize(dirichlet_neg_log_lik, np.ones(20), args=(historical_proportions,), bounds=[(0.01, None)]*20)
dirichlet_alpha_prior = res.x
print("Extracted Dirichlet prior:", dirichlet_alpha_prior)
# Save prior
np.save('dirichlet_prior.npy', dirichlet_alpha_prior)
# Out:
# Reading VCF file: ../../../data/vault_pipeline_output/SRR12676841_output/snp/all_snp_from_perfect_umi.vcf
# Loaded 82236 variants from VCF file
# Unique UMIs: 3658
# After PASS filter: 82236 variants (0 removed)
# INDELs included (encoded as continuous features)
# After VAF >= 0.15: 81379 variants (857 removed)
# After depth >= 5: 4127 variants (77252 removed)
# After alt reads >= 1: 4127 variants (0 removed)
# After frequency filter (min 18 occurrences): 125 variants (4002 removed)
#
# Final: 125 variants passed all filters (0.2%)
# Unique UMIs remaining: 113
# Encoding 125 INDELs as 3 features each (presence, length, type)
# Created variant matrix: (16674, 113)
# Total variants/features: 250
# Mean value per UMI: 0.00
# Sparsity: 0.999867
# Applied PCA: Reduced to 50 components
# Reading VCF file: ../../../data/vault_pipeline_output/SRR12676842_output/snp/all_snp_from_perfect_umi.vcf
# Loaded 141140 variants from VCF file
# Unique UMIs: 5368
# After PASS filter: 141140 variants (0 removed)
# INDELs included (encoded as continuous features)
# After VAF >= 0.15: 136612 variants (4528 removed)
# After depth >= 5: 14134 variants (122478 removed)
# After alt reads >= 1: 14134 variants (0 removed)
# After frequency filter (min 26 occurrences): 1783 variants (12351 removed)
#
# Final: 1783 variants passed all filters (1.3%)
# Unique UMIs remaining: 1016
# Encoding 1783 INDELs as 3 features each (presence, length, type)
# Created variant matrix: (21648, 1016)
# Total variants/features: 3674
# Mean value per UMI: 0.00
# Sparsity: 0.999833
# Applied PCA: Reduced to 50 components
# Reading VCF file: ../../../data/vault_pipeline_output/SRR12676843_output/snp/all_snp_from_perfect_umi.vcf
# Loaded 207634 variants from VCF file
# Unique UMIs: 7885
# After PASS filter: 207634 variants (0 removed)
# INDELs included (encoded as continuous features)
# After VAF >= 0.15: 202256 variants (5378 removed)
# After depth >= 5: 18264 variants (183992 removed)
# After alt reads >= 1: 18264 variants (0 removed)
# After frequency filter (min 39 occurrences): 1960 variants (16304 removed)
#
# Final: 1960 variants passed all filters (0.9%)
# Unique UMIs remaining: 1204
# Encoding 1960 INDELs as 3 features each (presence, length, type)
# Created variant matrix: (22179, 1204)
# Total variants/features: 3962
# Mean value per UMI: 0.00
# Sparsity: 0.999852
# Applied PCA: Reduced to 50 components
# Reading VCF file: ../../../data/vault_pipeline_output/SRR12676844_output/snp/all_snp_from_perfect_umi.vcf
# Loaded 201 variants from VCF file
# Unique UMIs: 16
# After PASS filter: 201 variants (0 removed)
# INDELs included (encoded as continuous features)
# After VAF >= 0.15: 201 variants (0 removed)
# After depth >= 5: 5 variants (196 removed)
# After alt reads >= 1: 5 variants (0 removed)
# After frequency filter (min 1 occurrences): 5 variants (0 removed)
#
# Final: 5 variants passed all filters (2.5%)
# Unique UMIs remaining: 2
# Encoding 5 INDELs as 3 features each (presence, length, type)
# Created variant matrix: (16314, 2)
# Total variants/features: 14
# Mean value per UMI: 0.00
# Sparsity: 0.999571
# Applied PCA: Reduced to 1 components
# /mmfs1/research/hhakimjavadi/projects/MitoDemon/repositories/MitoDemon/notebooks/../src/variant_clustering.py:70: UserWarning: Too few non-zero samples (2) for 20 clusters. Falling back to kmeans with reduced clusters.
#   warnings.warn(f"Too few non-zero samples ({n_non_zero}) for {self.n_clusters} clusters. Falling back to kmeans with reduced clusters.")
# Skipping ../../../data/vault_pipeline_output/SRR12676844_output/snp/all_snp_from_perfect_umi.vcf: insufficient clusters after filtering.
# Reading VCF file: ../../../data/vault_pipeline_output/SRR12676845_output/snp/all_snp_from_perfect_umi.vcf
# Loaded 90480 variants from VCF file
# Unique UMIs: 3456
# After PASS filter: 90480 variants (0 removed)
# INDELs included (encoded as continuous features)
# After VAF >= 0.15: 85833 variants (4647 removed)
# After depth >= 5: 11564 variants (74269 removed)
# After alt reads >= 1: 11564 variants (0 removed)
# After frequency filter (min 17 occurrences): 2499 variants (9065 removed)
#
# Final: 2499 variants passed all filters (2.8%)
# Unique UMIs remaining: 922
# Encoding 2499 INDELs as 3 features each (presence, length, type)
# Created variant matrix: (23796, 922)
# Total variants/features: 5055
# Mean value per UMI: 0.00
# Sparsity: 0.999770
# Applied PCA: Reduced to 50 components
# Reading VCF file: ../../../data/vault_pipeline_output/SRR12676846_output/snp/all_snp_from_perfect_umi.vcf
# Loaded 306583 variants from VCF file
# Unique UMIs: 10156
# After PASS filter: 306583 variants (0 removed)
# INDELs included (encoded as continuous features)
# After VAF >= 0.15: 294263 variants (12320 removed)
# After depth >= 5: 37074 variants (257189 removed)
# After alt reads >= 1: 37074 variants (0 removed)
# After frequency filter (min 50 occurrences): 3542 variants (33532 removed)
#
# Final: 3542 variants passed all filters (1.2%)
# Unique UMIs remaining: 2107
# Encoding 3542 INDELs as 3 features each (presence, length, type)
# Created variant matrix: (26925, 2107)
# Total variants/features: 7314
# Mean value per UMI: 0.00
# Sparsity: 0.999871
# Applied PCA: Reduced to 50 components
# Extracted Dirichlet prior: [3.46506445 2.93558677 2.9326775  1.11208531 1.39517287 1.45384502
#  1.85429328 0.9756511  1.36722484 1.306428   2.1668731  1.23476884
#  1.40233825 1.57612902 1.42571814 1.16599975 1.40341806 1.27534277
#  1.39223193 1.54707128]

# %%
# Load simulated/real data (example from previous notebook; adjust path if needed)
data_loader = np.load('../sc_mito_vars/real_data/imigseq_SRR12676843/numpy/vcf_processed_data.npz')
K_true = data_loader['K_true']  # Assume (n_positions x n_clusters); transpose if needed
C_observed = data_loader['C_observed']
# Load extracted prior
dirichlet_alpha_prior = np.load('dirichlet_prior.npy')
# Adjust shapes if necessary (ensure K is (n_clusters x n_positions) for matmul)
if K_true.shape[1] != len(dirichlet_alpha_prior):
    print("Warning: Prior dim mismatch; resizing prior.")
    dirichlet_alpha_prior = np.resize(dirichlet_alpha_prior, K_true.shape[1])
K_true = K_true.T  # Transpose to (n_clusters x n_positions)
# Deconvolve with Bayesian model (revised for stable sampling)
n_cells, n_positions = C_observed.shape
n_clusters = K_true.shape[0]  # Now n_clusters first
K_torch = torch.tensor(K_true, dtype=torch.float32)
C_torch = torch.tensor(C_observed, dtype=torch.float32)
alpha_prior = torch.tensor(dirichlet_alpha_prior, dtype=torch.float32)
def model(c_obs):
    p = pyro.sample("p", dist.Dirichlet(alpha_prior))
    with pyro.plate("data", n_positions):
        pyro.sample("obs", dist.Normal((p @ K_torch), 0.01), obs=c_obs)  # Adjusted matmul
def guide(c_obs):
    alpha_q = pyro.param("alpha_q", alpha_prior.clone(), constraint=dist.constraints.positive)
    pyro.sample("p", dist.Dirichlet(alpha_q))
p_estimated = np.zeros((n_cells, n_clusters))
p_uncertainty = np.zeros((n_cells, n_clusters))
for i in range(n_cells):
    svi = SVI(model, guide, Adam({"lr": 0.01}), Trace_ELBO())
    losses = []
    for step in range(1000):  # Increased steps for convergence
        loss = svi.step(C_torch[i])
        losses.append(loss)
        if step % 100 == 0:
            print(f"Cell {i}, Step {step}: Loss = {loss:.4f}")
    # Check convergence (simple threshold on final loss)
    if losses[-1] > 1e4:  # Arbitrary high loss threshold; adjust based on data
        print(f"Warning: High loss for cell {i}; using uniform fallback.")
        p_estimated[i] = np.ones(n_clusters) / n_clusters
        p_uncertainty[i] = np.ones(n_clusters) * 0.1  # Arbitrary uncertainty
        continue
    # Use Predictive for stable posterior sampling
    predictive = Predictive(model=guide, num_samples=1000, return_sites=("p",))
    samples = predictive(C_torch[i])
    p_samples = samples["p"].detach().numpy().squeeze()  # (1000 x n_clusters)
    p_estimated[i] = p_samples.mean(axis=0)
    p_uncertainty[i] = p_samples.std(axis=0)
print("Estimated proportions shape:", p_estimated.shape)
print("Uncertainty shape:", p_uncertainty.shape)
# Out:
# Cell 0, Step 0: Loss = -55885.8023
# Cell 0, Step 100: Loss = -55896.7790
# Cell 0, Step 200: Loss = -55895.5110
# Cell 0, Step 300: Loss = -55897.7501
# Cell 0, Step 400: Loss = -55899.6079
# Cell 0, Step 500: Loss = -55898.4413
# Cell 0, Step 600: Loss = -55899.4442
# Cell 0, Step 700: Loss = -55898.7081
# Cell 0, Step 800: Loss = -55898.5875
# Cell 0, Step 900: Loss = -55898.5439
# Cell 1, Step 0: Loss = -55863.6576
# Cell 1, Step 100: Loss = -55891.7153
# Cell 1, Step 200: Loss = -55898.4871
# Cell 1, Step 300: Loss = -55895.7755
# Cell 1, Step 400: Loss = -55895.1461
# Cell 1, Step 500: Loss = -55897.2187
# Cell 1, Step 600: Loss = -55895.5055
# Cell 1, Step 700: Loss = -55896.8284
# Cell 1, Step 800: Loss = -55895.1640
# Cell 1, Step 900: Loss = -55895.3329
# Cell 2, Step 0: Loss = -55846.2933
# Cell 2, Step 100: Loss = -55857.5576
# Cell 2, Step 200: Loss = -55860.5034
# Cell 2, Step 300: Loss = -55860.0893
# Cell 2, Step 400: Loss = -55861.0317
# Cell 2, Step 500: Loss = -55863.7628
# Cell 2, Step 600: Loss = -55861.8989
# Cell 2, Step 700: Loss = -55862.8215
# Cell 2, Step 800: Loss = -55861.3471
# Cell 2, Step 900: Loss = -55863.0869
# Cell 3, Step 0: Loss = -55986.1789
# Cell 3, Step 100: Loss = -55996.8098
# Cell 3, Step 200: Loss = -55998.0628
# Cell 3, Step 300: Loss = -55999.0347
# Cell 3, Step 400: Loss = -55999.0077
# Cell 3, Step 500: Loss = -55998.5336
# Cell 3, Step 600: Loss = -55998.7265
# Cell 3, Step 700: Loss = -55997.5358
# Cell 3, Step 800: Loss = -55998.6163
# Cell 3, Step 900: Loss = -55996.1677
# Cell 4, Step 0: Loss = -55919.0148
# Cell 4, Step 100: Loss = -55922.2541
# Cell 4, Step 200: Loss = -55925.3553
# Cell 4, Step 300: Loss = -55927.1918
# Cell 4, Step 400: Loss = -55925.8235
# Cell 4, Step 500: Loss = -55926.3693
# Cell 4, Step 600: Loss = -55925.5496
# Cell 4, Step 700: Loss = -55926.2364
# Cell 4, Step 800: Loss = -55927.0631
# Cell 4, Step 900: Loss = -55926.2741
# Cell 5, Step 0: Loss = -56039.2532
# Cell 5, Step 100: Loss = -56050.6812
# Cell 5, Step 200: Loss = -56058.0865
# Cell 5, Step 300: Loss = -56057.6293
# Cell 5, Step 400: Loss = -56056.1224
# Cell 5, Step 500: Loss = -56056.4978
# Cell 5, Step 600: Loss = -56057.5438
# Cell 5, Step 700: Loss = -56054.8644
# Cell 5, Step 800: Loss = -56058.7198
# Cell 5, Step 900: Loss = -56056.8826
# Cell 6, Step 0: Loss = -55897.4481
# Cell 6, Step 100: Loss = -55932.5853
# Cell 6, Step 200: Loss = -55933.4689
# Cell 6, Step 300: Loss = -55937.4502
# Cell 6, Step 400: Loss = -55938.4083
# Cell 6, Step 500: Loss = -55937.4540
# Cell 6, Step 600: Loss = -55935.8487
# Cell 6, Step 700: Loss = -55935.0697
# Cell 6, Step 800: Loss = -55934.0854
# Cell 6, Step 900: Loss = -55936.6397
# Cell 7, Step 0: Loss = -55971.3635
# Cell 7, Step 100: Loss = -55974.3520
# Cell 7, Step 200: Loss = -55975.0528
# Cell 7, Step 300: Loss = -55975.8932
# Cell 7, Step 400: Loss = -55977.4585
# Cell 7, Step 500: Loss = -55973.6370
# Cell 7, Step 600: Loss = -55974.5990
# Cell 7, Step 700: Loss = -55974.4384
# Cell 7, Step 800: Loss = -55973.3998
# Cell 7, Step 900: Loss = -55976.0718
# Cell 8, Step 0: Loss = -55963.6615
# Cell 8, Step 100: Loss = -55989.4058
# Cell 8, Step 200: Loss = -55992.0098
# Cell 8, Step 300: Loss = -55985.3570
# Cell 8, Step 400: Loss = -55989.8669
# Cell 8, Step 500: Loss = -55989.6542
# Cell 8, Step 600: Loss = -55990.1114
# Cell 8, Step 700: Loss = -55990.2102
# Cell 8, Step 800: Loss = -55977.1118
# Cell 8, Step 900: Loss = -55987.5482
# Cell 9, Step 0: Loss = -55847.8392
# Cell 9, Step 100: Loss = -55867.6014
# Cell 9, Step 200: Loss = -55866.8498
# Cell 9, Step 300: Loss = -55869.9422
# Cell 9, Step 400: Loss = -55869.8107
# Cell 9, Step 500: Loss = -55870.1574
# Cell 9, Step 600: Loss = -55870.2453
# Cell 9, Step 700: Loss = -55872.0580
# Cell 9, Step 800: Loss = -55870.4554
# Cell 9, Step 900: Loss = -55871.0784
# Cell 10, Step 0: Loss = -55822.6658
# Cell 10, Step 100: Loss = -55835.9842
# Cell 10, Step 200: Loss = -55835.6053
# Cell 10, Step 300: Loss = -55834.2462
# Cell 10, Step 400: Loss = -55834.9524
# Cell 10, Step 500: Loss = -55836.9482
# Cell 10, Step 600: Loss = -55833.7769
# Cell 10, Step 700: Loss = -55835.9199
# Cell 10, Step 800: Loss = -55836.0807
# Cell 10, Step 900: Loss = -55836.0011
# Cell 11, Step 0: Loss = -55895.0841
# Cell 11, Step 100: Loss = -55911.2336
# Cell 11, Step 200: Loss = -55911.0858
# Cell 11, Step 300: Loss = -55912.5486
# Cell 11, Step 400: Loss = -55912.0610
# Cell 11, Step 500: Loss = -55912.0102
# Cell 11, Step 600: Loss = -55912.8842
# Cell 11, Step 700: Loss = -55913.6561
# Cell 11, Step 800: Loss = -55912.4872
# Cell 11, Step 900: Loss = -55911.4549
# Cell 12, Step 0: Loss = -55962.1364
# Cell 12, Step 100: Loss = -55974.3097
# Cell 12, Step 200: Loss = -55973.8382
# Cell 12, Step 300: Loss = -55975.0114
# Cell 12, Step 400: Loss = -55975.6634
# Cell 12, Step 500: Loss = -55974.1318
# Cell 12, Step 600: Loss = -55972.1511
# Cell 12, Step 700: Loss = -55974.3396
# Cell 12, Step 800: Loss = -55974.5685
# Cell 12, Step 900: Loss = -55974.9093
# Cell 13, Step 0: Loss = -56045.2833
# Cell 13, Step 100: Loss = -56048.5454
# Cell 13, Step 200: Loss = -56050.8432
# Cell 13, Step 300: Loss = -56050.2648
# Cell 13, Step 400: Loss = -56050.8486
# Cell 13, Step 500: Loss = -56050.6184
# Cell 13, Step 600: Loss = -56049.8843
# Cell 13, Step 700: Loss = -56050.4964
# Cell 13, Step 800: Loss = -56050.2438
# Cell 13, Step 900: Loss = -56050.1162
# Cell 14, Step 0: Loss = -55845.4058
# Cell 14, Step 100: Loss = -55854.3753
# Cell 14, Step 200: Loss = -55852.0397
# Cell 14, Step 300: Loss = -55854.7062
# Cell 14, Step 400: Loss = -55851.3872
# Cell 14, Step 500: Loss = -55851.2878
# Cell 14, Step 600: Loss = -55854.0606
# Cell 14, Step 700: Loss = -55852.0496
# Cell 14, Step 800: Loss = -55852.5206
# Cell 14, Step 900: Loss = -55853.0531
# Cell 15, Step 0: Loss = -55875.3076
# Cell 15, Step 100: Loss = -55880.3413
# Cell 15, Step 200: Loss = -55877.4814
# Cell 15, Step 300: Loss = -55880.3146
# Cell 15, Step 400: Loss = -55883.0694
# Cell 15, Step 500: Loss = -55865.2164
# Cell 15, Step 600: Loss = -55882.2244
# Cell 15, Step 700: Loss = -55883.5141
# Cell 15, Step 800: Loss = -55882.7157
# Cell 15, Step 900: Loss = -55882.0383
# Cell 16, Step 0: Loss = -55882.0718
# Cell 16, Step 100: Loss = -55883.1329
# Cell 16, Step 200: Loss = -55884.2784
# Cell 16, Step 300: Loss = -55885.0613
# Cell 16, Step 400: Loss = -55886.2194
# Cell 16, Step 500: Loss = -55884.2709
# Cell 16, Step 600: Loss = -55884.3718
# Cell 16, Step 700: Loss = -55885.8807
# Cell 16, Step 800: Loss = -55886.6261
# Cell 16, Step 900: Loss = -55883.5970
# Cell 17, Step 0: Loss = -55951.2255
# Cell 17, Step 100: Loss = -55958.7598
# Cell 17, Step 200: Loss = -55960.2879
# Cell 17, Step 300: Loss = -55959.4574
# Cell 17, Step 400: Loss = -55958.8877
# Cell 17, Step 500: Loss = -55959.5903
# Cell 17, Step 600: Loss = -55960.4634
# Cell 17, Step 700: Loss = -55959.0747
# Cell 17, Step 800: Loss = -55958.9651
# Cell 17, Step 900: Loss = -55959.1049
# Cell 18, Step 0: Loss = -55954.2469
# Cell 18, Step 100: Loss = -55952.8732
# Cell 18, Step 200: Loss = -55955.7536
# Cell 18, Step 300: Loss = -55954.5260
# Cell 18, Step 400: Loss = -55954.8840
# Cell 18, Step 500: Loss = -55954.1367
# Cell 18, Step 600: Loss = -55953.4670
# Cell 18, Step 700: Loss = -55954.2939
# Cell 18, Step 800: Loss = -55952.7266
# Cell 18, Step 900: Loss = -55955.7372
# Cell 19, Step 0: Loss = -55837.7456
# Cell 19, Step 100: Loss = -55844.6559
# Cell 19, Step 200: Loss = -55844.4212
# Cell 19, Step 300: Loss = -55843.3559
# Cell 19, Step 400: Loss = -55845.2654
# Cell 19, Step 500: Loss = -55844.3548
# Cell 19, Step 600: Loss = -55845.1096
# Cell 19, Step 700: Loss = -55846.9843
# Cell 19, Step 800: Loss = -55844.8122
# Cell 19, Step 900: Loss = -55845.2077
# Cell 20, Step 0: Loss = -55866.9885
# Cell 20, Step 100: Loss = -55872.3758
# Cell 20, Step 200: Loss = -55876.2527
# Cell 20, Step 300: Loss = -55874.0836
# Cell 20, Step 400: Loss = -55877.9517
# Cell 20, Step 500: Loss = -55875.3751
# Cell 20, Step 600: Loss = -55875.0955
# Cell 20, Step 700: Loss = -55875.7887
# Cell 20, Step 800: Loss = -55875.9626
# Cell 20, Step 900: Loss = -55876.6134
# Cell 21, Step 0: Loss = -55943.0724
# Cell 21, Step 100: Loss = -55950.7397
# Cell 21, Step 200: Loss = -55948.8535
# Cell 21, Step 300: Loss = -55948.3715
# Cell 21, Step 400: Loss = -55947.6534
# Cell 21, Step 500: Loss = -55947.6890
# Cell 21, Step 600: Loss = -55950.8093
# Cell 21, Step 700: Loss = -55947.7944
# Cell 21, Step 800: Loss = -55948.5171
# Cell 21, Step 900: Loss = -55949.0078
# Cell 22, Step 0: Loss = -55893.2582
# Cell 22, Step 100: Loss = -55905.5808
# Cell 22, Step 200: Loss = -55906.3889
# Cell 22, Step 300: Loss = -55904.7158
# Cell 22, Step 400: Loss = -55903.2050
# Cell 22, Step 500: Loss = -55904.2622
# Cell 22, Step 600: Loss = -55901.6752
# Cell 22, Step 700: Loss = -55903.8881
# Cell 22, Step 800: Loss = -55904.7617
# Cell 22, Step 900: Loss = -55906.4405
# Cell 23, Step 0: Loss = -55995.7058
# Cell 23, Step 100: Loss = -56013.1861
# Cell 23, Step 200: Loss = -56016.0493
# Cell 23, Step 300: Loss = -56013.2049
# Cell 23, Step 400: Loss = -56016.8019
# Cell 23, Step 500: Loss = -56016.9643
# Cell 23, Step 600: Loss = -56016.9845
# Cell 23, Step 700: Loss = -56017.0124
# Cell 23, Step 800: Loss = -56014.7119
# Cell 23, Step 900: Loss = -56010.3616
# Cell 24, Step 0: Loss = -55877.4453
# Cell 24, Step 100: Loss = -55879.2212
# Cell 24, Step 200: Loss = -55880.4604
# Cell 24, Step 300: Loss = -55878.0480
# Cell 24, Step 400: Loss = -55880.5468
# Cell 24, Step 500: Loss = -55878.2953
# Cell 24, Step 600: Loss = -55880.7675
# Cell 24, Step 700: Loss = -55880.2795
# Cell 24, Step 800: Loss = -55878.9680
# Cell 24, Step 900: Loss = -55878.4399
# Cell 25, Step 0: Loss = -55930.5525
# Cell 25, Step 100: Loss = -55938.5645
# Cell 25, Step 200: Loss = -55938.2581
# Cell 25, Step 300: Loss = -55938.9952
# Cell 25, Step 400: Loss = -55938.6848
# Cell 25, Step 500: Loss = -55938.8550
# Cell 25, Step 600: Loss = -55938.6850
# Cell 25, Step 700: Loss = -55938.6958
# Cell 25, Step 800: Loss = -55936.8439
# Cell 25, Step 900: Loss = -55938.5440
# Cell 26, Step 0: Loss = -55920.1221
# Cell 26, Step 100: Loss = -55931.2373
# Cell 26, Step 200: Loss = -55935.3347
# Cell 26, Step 300: Loss = -55937.6537
# Cell 26, Step 400: Loss = -55937.8844
# Cell 26, Step 500: Loss = -55939.1185
# Cell 26, Step 600: Loss = -55932.4178
# Cell 26, Step 700: Loss = -55937.8767
# Cell 26, Step 800: Loss = -55935.9410
# Cell 26, Step 900: Loss = -55939.0627
# Cell 27, Step 0: Loss = -55904.0749
# Cell 27, Step 100: Loss = -55905.7773
# Cell 27, Step 200: Loss = -55904.4185
# Cell 27, Step 300: Loss = -55906.7247
# Cell 27, Step 400: Loss = -55907.0118
# Cell 27, Step 500: Loss = -55905.4724
# Cell 27, Step 600: Loss = -55908.0745
# Cell 27, Step 700: Loss = -55905.5029
# Cell 27, Step 800: Loss = -55907.1912
# Cell 27, Step 900: Loss = -55903.8461
# Cell 28, Step 0: Loss = -55975.8755
# Cell 28, Step 100: Loss = -56006.8647
# Cell 28, Step 200: Loss = -56006.6723
# Cell 28, Step 300: Loss = -56006.5434
# Cell 28, Step 400: Loss = -56007.0989
# Cell 28, Step 500: Loss = -56005.2151
# Cell 28, Step 600: Loss = -56003.3216
# Cell 28, Step 700: Loss = -56004.8341
# Cell 28, Step 800: Loss = -56004.6565
# Cell 28, Step 900: Loss = -56006.2331
# Cell 29, Step 0: Loss = -56001.2941
# Cell 29, Step 100: Loss = -56024.0756
# Cell 29, Step 200: Loss = -56021.6905
# Cell 29, Step 300: Loss = -56023.8747
# Cell 29, Step 400: Loss = -56022.0109
# Cell 29, Step 500: Loss = -56022.4942
# Cell 29, Step 600: Loss = -56022.1401
# Cell 29, Step 700: Loss = -56023.4371
# Cell 29, Step 800: Loss = -56021.9273
# Cell 29, Step 900: Loss = -56021.3799
# Cell 30, Step 0: Loss = -55838.1204
# Cell 30, Step 100: Loss = -55848.6480
# Cell 30, Step 200: Loss = -55850.6147
# Cell 30, Step 300: Loss = -55849.8788
# Cell 30, Step 400: Loss = -55851.1787
# Cell 30, Step 500: Loss = -55850.1577
# Cell 30, Step 600: Loss = -55850.8063
# Cell 30, Step 700: Loss = -55851.3830
# Cell 30, Step 800: Loss = -55852.4677
# Cell 30, Step 900: Loss = -55850.8414
# Cell 31, Step 0: Loss = -55982.8304
# Cell 31, Step 100: Loss = -55991.5773
# Cell 31, Step 200: Loss = -55986.4237
# Cell 31, Step 300: Loss = -55990.0422
# Cell 31, Step 400: Loss = -55988.0943
# Cell 31, Step 500: Loss = -55990.8552
# Cell 31, Step 600: Loss = -55990.3600
# Cell 31, Step 700: Loss = -55987.7165
# Cell 31, Step 800: Loss = -55991.7449
# Cell 31, Step 900: Loss = -55992.2772
# Cell 32, Step 0: Loss = -55984.0044
# Cell 32, Step 100: Loss = -56002.0336
# Cell 32, Step 200: Loss = -56005.2574
# Cell 32, Step 300: Loss = -56004.9223
# Cell 32, Step 400: Loss = -56006.0910
# Cell 32, Step 500: Loss = -56005.8476
# Cell 32, Step 600: Loss = -56004.7395
# Cell 32, Step 700: Loss = -56004.3510
# Cell 32, Step 800: Loss = -56004.8909
# Cell 32, Step 900: Loss = -56005.4564
# Cell 33, Step 0: Loss = -56050.9084
# Cell 33, Step 100: Loss = -56066.4563
# Cell 33, Step 200: Loss = -56065.9784
# Cell 33, Step 300: Loss = -56067.5764
# Cell 33, Step 400: Loss = -56065.6166
# Cell 33, Step 500: Loss = -56065.8057
# Cell 33, Step 600: Loss = -56067.7162
# Cell 33, Step 700: Loss = -56067.2199
# Cell 33, Step 800: Loss = -56068.4192
# Cell 33, Step 900: Loss = -56066.9637
# Cell 34, Step 0: Loss = -55977.6637
# Cell 34, Step 100: Loss = -55994.8264
# Cell 34, Step 200: Loss = -55992.5955
# Cell 34, Step 300: Loss = -55995.0909
# Cell 34, Step 400: Loss = -55994.0579
# Cell 34, Step 500: Loss = -55995.9682
# Cell 34, Step 600: Loss = -55993.9939
# Cell 34, Step 700: Loss = -55994.4132
# Cell 34, Step 800: Loss = -55993.7894
# Cell 34, Step 900: Loss = -55994.6676
# Cell 35, Step 0: Loss = -55833.6463
# Cell 35, Step 100: Loss = -55843.0638
# Cell 35, Step 200: Loss = -55843.7851
# Cell 35, Step 300: Loss = -55842.6948
# Cell 35, Step 400: Loss = -55843.4411
# Cell 35, Step 500: Loss = -55843.5787
# Cell 35, Step 600: Loss = -55844.4143
# Cell 35, Step 700: Loss = -55843.3856
# Cell 35, Step 800: Loss = -55842.9478
# Cell 35, Step 900: Loss = -55844.2755
# Cell 36, Step 0: Loss = -55852.3004
# Cell 36, Step 100: Loss = -55875.1042
# Cell 36, Step 200: Loss = -55868.8296
# Cell 36, Step 300: Loss = -55866.2811
# Cell 36, Step 400: Loss = -55869.3301
# Cell 36, Step 500: Loss = -55868.8958
# Cell 36, Step 600: Loss = -55871.9110
# Cell 36, Step 700: Loss = -55868.4945
# Cell 36, Step 800: Loss = -55869.8723
# Cell 36, Step 900: Loss = -55871.1673
# Cell 37, Step 0: Loss = -55809.1341
# Cell 37, Step 100: Loss = -55831.3752
# Cell 37, Step 200: Loss = -55841.9104
# Cell 37, Step 300: Loss = -55841.8737
# Cell 37, Step 400: Loss = -55843.1942
# Cell 37, Step 500: Loss = -55842.4949
# Cell 37, Step 600: Loss = -55844.0882
# Cell 37, Step 700: Loss = -55843.5087
# Cell 37, Step 800: Loss = -55843.3989
# Cell 37, Step 900: Loss = -55841.6092
# Cell 38, Step 0: Loss = -55917.4228
# Cell 38, Step 100: Loss = -55920.9770
# Cell 38, Step 200: Loss = -55928.3902
# Cell 38, Step 300: Loss = -55926.2181
# Cell 38, Step 400: Loss = -55930.5555
# Cell 38, Step 500: Loss = -55928.7088
# Cell 38, Step 600: Loss = -55925.6983
# Cell 38, Step 700: Loss = -55928.3110
# Cell 38, Step 800: Loss = -55928.2491
# Cell 38, Step 900: Loss = -55927.0839
# Cell 39, Step 0: Loss = -55968.4901
# Cell 39, Step 100: Loss = -55991.0943
# Cell 39, Step 200: Loss = -55991.2908
# Cell 39, Step 300: Loss = -55992.8265
# Cell 39, Step 400: Loss = -55989.2885
# Cell 39, Step 500: Loss = -55990.1802
# Cell 39, Step 600: Loss = -55992.0266
# Cell 39, Step 700: Loss = -55991.9923
# Cell 39, Step 800: Loss = -55992.1329
# Cell 39, Step 900: Loss = -55991.5395
# Cell 40, Step 0: Loss = -55944.4793
# Cell 40, Step 100: Loss = -55957.2853
# Cell 40, Step 200: Loss = -55955.7890
# Cell 40, Step 300: Loss = -55954.9062
# Cell 40, Step 400: Loss = -55957.0338
# Cell 40, Step 500: Loss = -55955.6550
# Cell 40, Step 600: Loss = -55959.1779
# Cell 40, Step 700: Loss = -55953.3418
# Cell 40, Step 800: Loss = -55955.7115
# Cell 40, Step 900: Loss = -55955.2741
# Cell 41, Step 0: Loss = -55927.2235
# Cell 41, Step 100: Loss = -55942.5200
# Cell 41, Step 200: Loss = -55941.2848
# Cell 41, Step 300: Loss = -55939.3727
# Cell 41, Step 400: Loss = -55938.0807
# Cell 41, Step 500: Loss = -55939.3284
# Cell 41, Step 600: Loss = -55941.3825
# Cell 41, Step 700: Loss = -55941.7113
# Cell 41, Step 800: Loss = -55941.1554
# Cell 41, Step 900: Loss = -55940.0127
# Cell 42, Step 0: Loss = -55875.6426
# Cell 42, Step 100: Loss = -55871.0238
# Cell 42, Step 200: Loss = -55873.9634
# Cell 42, Step 300: Loss = -55872.7951
# Cell 42, Step 400: Loss = -55872.7678
# Cell 42, Step 500: Loss = -55873.4176
# Cell 42, Step 600: Loss = -55871.7838
# Cell 42, Step 700: Loss = -55873.6481
# Cell 42, Step 800: Loss = -55873.0971
# Cell 42, Step 900: Loss = -55872.4543
# Cell 43, Step 0: Loss = -55938.3510
# Cell 43, Step 100: Loss = -55949.8736
# Cell 43, Step 200: Loss = -55949.9682
# Cell 43, Step 300: Loss = -55948.9510
# Cell 43, Step 400: Loss = -55949.8536
# Cell 43, Step 500: Loss = -55953.0123
# Cell 43, Step 600: Loss = -55948.8579
# Cell 43, Step 700: Loss = -55951.1461
# Cell 43, Step 800: Loss = -55949.8459
# Cell 43, Step 900: Loss = -55949.3154
# Cell 44, Step 0: Loss = -55966.6541
# Cell 44, Step 100: Loss = -55973.3149
# Cell 44, Step 200: Loss = -55974.5775
# Cell 44, Step 300: Loss = -55975.2785
# Cell 44, Step 400: Loss = -55976.9090
# Cell 44, Step 500: Loss = -55972.1857
# Cell 44, Step 600: Loss = -55975.2778
# Cell 44, Step 700: Loss = -55974.2758
# Cell 44, Step 800: Loss = -55976.1887
# Cell 44, Step 900: Loss = -55975.4590
# Cell 45, Step 0: Loss = -55955.6225
# Cell 45, Step 100: Loss = -55964.7705
# Cell 45, Step 200: Loss = -55963.2997
# Cell 45, Step 300: Loss = -55966.5174
# Cell 45, Step 400: Loss = -55964.2082
# Cell 45, Step 500: Loss = -55964.4101
# Cell 45, Step 600: Loss = -55964.1379
# Cell 45, Step 700: Loss = -55966.2911
# Cell 45, Step 800: Loss = -55965.1161
# Cell 45, Step 900: Loss = -55965.4282
# Cell 46, Step 0: Loss = -55758.9641
# Cell 46, Step 100: Loss = -55760.9587
# Cell 46, Step 200: Loss = -55761.2599
# Cell 46, Step 300: Loss = -55760.1335
# Cell 46, Step 400: Loss = -55762.5670
# Cell 46, Step 500: Loss = -55760.3548
# Cell 46, Step 600: Loss = -55760.5707
# Cell 46, Step 700: Loss = -55760.7759
# Cell 46, Step 800: Loss = -55759.0830
# Cell 46, Step 900: Loss = -55760.4237
# Cell 47, Step 0: Loss = -55856.5970
# Cell 47, Step 100: Loss = -55863.8707
# Cell 47, Step 200: Loss = -55864.6631
# Cell 47, Step 300: Loss = -55868.5245
# Cell 47, Step 400: Loss = -55864.9574
# Cell 47, Step 500: Loss = -55867.2719
# Cell 47, Step 600: Loss = -55866.7777
# Cell 47, Step 700: Loss = -55865.0964
# Cell 47, Step 800: Loss = -55865.8604
# Cell 47, Step 900: Loss = -55867.7092
# Cell 48, Step 0: Loss = -55828.1301
# Cell 48, Step 100: Loss = -55838.8977
# Cell 48, Step 200: Loss = -55835.5431
# Cell 48, Step 300: Loss = -55840.1707
# Cell 48, Step 400: Loss = -55838.6627
# Cell 48, Step 500: Loss = -55838.9228
# Cell 48, Step 600: Loss = -55838.3174
# Cell 48, Step 700: Loss = -55837.7825
# Cell 48, Step 800: Loss = -55836.7753
# Cell 48, Step 900: Loss = -55837.4145
# Cell 49, Step 0: Loss = -55805.9230
# Cell 49, Step 100: Loss = -55834.8157
# Cell 49, Step 200: Loss = -55836.7601
# Cell 49, Step 300: Loss = -55836.2932
# Cell 49, Step 400: Loss = -55836.3944
# Cell 49, Step 500: Loss = -55835.6823
# Cell 49, Step 600: Loss = -55835.8658
# Cell 49, Step 700: Loss = -55835.8368
# Cell 49, Step 800: Loss = -55834.6607
# Cell 49, Step 900: Loss = -55828.4214
# Cell 50, Step 0: Loss = -55940.4358
# Cell 50, Step 100: Loss = -55970.7923
# Cell 50, Step 200: Loss = -55969.9024
# Cell 50, Step 300: Loss = -55973.9742
# Cell 50, Step 400: Loss = -55974.4752
# Cell 50, Step 500: Loss = -55971.7258
# Cell 50, Step 600: Loss = -55973.2098
# Cell 50, Step 700: Loss = -55973.6991
# Cell 50, Step 800: Loss = -55970.0971
# Cell 50, Step 900: Loss = -55972.6873
# Cell 51, Step 0: Loss = -56073.2415
# Cell 51, Step 100: Loss = -56090.0662
# Cell 51, Step 200: Loss = -56096.8098
# Cell 51, Step 300: Loss = -56094.3118
# Cell 51, Step 400: Loss = -56095.0829
# Cell 51, Step 500: Loss = -56098.4663
# Cell 51, Step 600: Loss = -56097.3932
# Cell 51, Step 700: Loss = -56095.0925
# Cell 51, Step 800: Loss = -56097.3989
# Cell 51, Step 900: Loss = -56095.0546
# Cell 52, Step 0: Loss = -55962.7386
# Cell 52, Step 100: Loss = -55968.5710
# Cell 52, Step 200: Loss = -55968.2595
# Cell 52, Step 300: Loss = -55968.8583
# Cell 52, Step 400: Loss = -55968.2078
# Cell 52, Step 500: Loss = -55967.9457
# Cell 52, Step 600: Loss = -55968.7029
# Cell 52, Step 700: Loss = -55969.0450
# Cell 52, Step 800: Loss = -55967.5484
# Cell 52, Step 900: Loss = -55968.7387
# Cell 53, Step 0: Loss = -56032.7956
# Cell 53, Step 100: Loss = -56043.6558
# Cell 53, Step 200: Loss = -56042.3213
# Cell 53, Step 300: Loss = -56044.5052
# Cell 53, Step 400: Loss = -56041.3672
# Cell 53, Step 500: Loss = -56043.1011
# Cell 53, Step 600: Loss = -56043.2997
# Cell 53, Step 700: Loss = -56043.8083
# Cell 53, Step 800: Loss = -56041.9763
# Cell 53, Step 900: Loss = -56040.4424
# Cell 54, Step 0: Loss = -56034.4367
# Cell 54, Step 100: Loss = -56052.8345
# Cell 54, Step 200: Loss = -56052.7838
# Cell 54, Step 300: Loss = -56052.0424
# Cell 54, Step 400: Loss = -56054.0153
# Cell 54, Step 500: Loss = -56054.1198
# Cell 54, Step 600: Loss = -56054.2506
# Cell 54, Step 700: Loss = -56053.3400
# Cell 54, Step 800: Loss = -56053.3953
# Cell 54, Step 900: Loss = -56054.8745
# Cell 55, Step 0: Loss = -55977.9706
# Cell 55, Step 100: Loss = -55981.3845
# Cell 55, Step 200: Loss = -55980.5989
# Cell 55, Step 300: Loss = -55978.6761
# Cell 55, Step 400: Loss = -55980.4730
# Cell 55, Step 500: Loss = -55980.0316
# Cell 55, Step 600: Loss = -55980.0401
# Cell 55, Step 700: Loss = -55979.5645
# Cell 55, Step 800: Loss = -55979.3223
# Cell 55, Step 900: Loss = -55979.3008
# Cell 56, Step 0: Loss = -55943.5715
# Cell 56, Step 100: Loss = -55949.8329
# Cell 56, Step 200: Loss = -55947.8263
# Cell 56, Step 300: Loss = -55949.4322
# Cell 56, Step 400: Loss = -55950.1596
# Cell 56, Step 500: Loss = -55948.2140
# Cell 56, Step 600: Loss = -55946.1891
# Cell 56, Step 700: Loss = -55950.3983
# Cell 56, Step 800: Loss = -55945.9520
# Cell 56, Step 900: Loss = -55950.6966
# Cell 57, Step 0: Loss = -55844.6349
# Cell 57, Step 100: Loss = -55859.4232
# Cell 57, Step 200: Loss = -55861.0691
# Cell 57, Step 300: Loss = -55860.1534
# Cell 57, Step 400: Loss = -55861.0873
# Cell 57, Step 500: Loss = -55861.9178
# Cell 57, Step 600: Loss = -55859.5074
# Cell 57, Step 700: Loss = -55861.2954
# Cell 57, Step 800: Loss = -55862.3086
# Cell 57, Step 900: Loss = -55861.5024
# Cell 58, Step 0: Loss = -55943.8252
# Cell 58, Step 100: Loss = -55949.3872
# Cell 58, Step 200: Loss = -55950.2416
# Cell 58, Step 300: Loss = -55950.2505
# Cell 58, Step 400: Loss = -55950.9731
# Cell 58, Step 500: Loss = -55949.2514
# Cell 58, Step 600: Loss = -55951.3576
# Cell 58, Step 700: Loss = -55951.1023
# Cell 58, Step 800: Loss = -55950.0423
# Cell 58, Step 900: Loss = -55949.1945
# Cell 59, Step 0: Loss = -55848.4167
# Cell 59, Step 100: Loss = -55854.9836
# Cell 59, Step 200: Loss = -55856.3697
# Cell 59, Step 300: Loss = -55858.7452
# Cell 59, Step 400: Loss = -55857.6725
# Cell 59, Step 500: Loss = -55854.2383
# Cell 59, Step 600: Loss = -55856.5347
# Cell 59, Step 700: Loss = -55856.7709
# Cell 59, Step 800: Loss = -55856.3292
# Cell 59, Step 900: Loss = -55857.6549
# Cell 60, Step 0: Loss = -55766.3756
# Cell 60, Step 100: Loss = -55790.9196
# Cell 60, Step 200: Loss = -55793.7771
# Cell 60, Step 300: Loss = -55795.0967
# Cell 60, Step 400: Loss = -55793.8087
# Cell 60, Step 500: Loss = -55795.1531
# Cell 60, Step 600: Loss = -55794.0970
# Cell 60, Step 700: Loss = -55796.5005
# Cell 60, Step 800: Loss = -55793.2186
# Cell 60, Step 900: Loss = -55792.3776
# Cell 61, Step 0: Loss = -55900.9305
# Cell 61, Step 100: Loss = -55918.9479
# Cell 61, Step 200: Loss = -55922.7119
# Cell 61, Step 300: Loss = -55921.4769
# Cell 61, Step 400: Loss = -55922.6768
# Cell 61, Step 500: Loss = -55922.8827
# Cell 61, Step 600: Loss = -55921.4580
# Cell 61, Step 700: Loss = -55924.5207
# Cell 61, Step 800: Loss = -55922.0456
# Cell 61, Step 900: Loss = -55923.1860
# Cell 62, Step 0: Loss = -55818.4709
# Cell 62, Step 100: Loss = -55847.9872
# Cell 62, Step 200: Loss = -55846.2904
# Cell 62, Step 300: Loss = -55845.7559
# Cell 62, Step 400: Loss = -55848.1688
# Cell 62, Step 500: Loss = -55845.3414
# Cell 62, Step 600: Loss = -55844.0890
# Cell 62, Step 700: Loss = -55846.4529
# Cell 62, Step 800: Loss = -55846.3993
# Cell 62, Step 900: Loss = -55845.4367
# Cell 63, Step 0: Loss = -55913.0306
# Cell 63, Step 100: Loss = -55922.0999
# Cell 63, Step 200: Loss = -55921.8051
# Cell 63, Step 300: Loss = -55922.7964
# Cell 63, Step 400: Loss = -55918.5305
# Cell 63, Step 500: Loss = -55922.8420
# Cell 63, Step 600: Loss = -55921.1292
# Cell 63, Step 700: Loss = -55922.1538
# Cell 63, Step 800: Loss = -55920.2452
# Cell 63, Step 900: Loss = -55922.6734
# Cell 64, Step 0: Loss = -55992.9524
# Cell 64, Step 100: Loss = -55995.2442
# Cell 64, Step 200: Loss = -55997.4110
# Cell 64, Step 300: Loss = -55996.8570
# Cell 64, Step 400: Loss = -55997.4975
# Cell 64, Step 500: Loss = -55995.6523
# Cell 64, Step 600: Loss = -55997.0256
# Cell 64, Step 700: Loss = -55995.5665
# Cell 64, Step 800: Loss = -55996.7478
# Cell 64, Step 900: Loss = -55993.5020
# Cell 65, Step 0: Loss = -55926.5763
# Cell 65, Step 100: Loss = -55930.2681
# Cell 65, Step 200: Loss = -55929.9705
# Cell 65, Step 300: Loss = -55927.0255
# Cell 65, Step 400: Loss = -55928.6400
# Cell 65, Step 500: Loss = -55928.0358
# Cell 65, Step 600: Loss = -55928.0149
# Cell 65, Step 700: Loss = -55928.8479
# Cell 65, Step 800: Loss = -55929.3907
# Cell 65, Step 900: Loss = -55930.3688
# Cell 66, Step 0: Loss = -55922.2015
# Cell 66, Step 100: Loss = -55928.9484
# Cell 66, Step 200: Loss = -55930.7676
# Cell 66, Step 300: Loss = -55927.4834
# Cell 66, Step 400: Loss = -55927.2937
# Cell 66, Step 500: Loss = -55926.9695
# Cell 66, Step 600: Loss = -55928.3299
# Cell 66, Step 700: Loss = -55928.9603
# Cell 66, Step 800: Loss = -55928.0669
# Cell 66, Step 900: Loss = -55929.1136
# Cell 67, Step 0: Loss = -55915.8543
# Cell 67, Step 100: Loss = -55926.1819
# Cell 67, Step 200: Loss = -55926.6460
# Cell 67, Step 300: Loss = -55926.5736
# Cell 67, Step 400: Loss = -55927.6698
# Cell 67, Step 500: Loss = -55927.4768
# Cell 67, Step 600: Loss = -55926.9641
# Cell 67, Step 700: Loss = -55927.0878
# Cell 67, Step 800: Loss = -55927.5119
# Cell 67, Step 900: Loss = -55927.6932
# Cell 68, Step 0: Loss = -55896.7964
# Cell 68, Step 100: Loss = -55906.3073
# Cell 68, Step 200: Loss = -55907.8506
# Cell 68, Step 300: Loss = -55903.1817
# Cell 68, Step 400: Loss = -55904.6378
# Cell 68, Step 500: Loss = -55907.2714
# Cell 68, Step 600: Loss = -55906.3334
# Cell 68, Step 700: Loss = -55906.9359
# Cell 68, Step 800: Loss = -55902.5521
# Cell 68, Step 900: Loss = -55905.9847
# Cell 69, Step 0: Loss = -55929.6131
# Cell 69, Step 100: Loss = -55941.7161
# Cell 69, Step 200: Loss = -55944.1803
# Cell 69, Step 300: Loss = -55944.3708
# Cell 69, Step 400: Loss = -55943.7218
# Cell 69, Step 500: Loss = -55944.2556
# Cell 69, Step 600: Loss = -55944.4162
# Cell 69, Step 700: Loss = -55939.7683
# Cell 69, Step 800: Loss = -55940.3797
# Cell 69, Step 900: Loss = -55944.2376
# Cell 70, Step 0: Loss = -55890.7762
# Cell 70, Step 100: Loss = -55894.4603
# Cell 70, Step 200: Loss = -55896.1703
# Cell 70, Step 300: Loss = -55886.7999
# Cell 70, Step 400: Loss = -55896.3118
# Cell 70, Step 500: Loss = -55893.8812
# Cell 70, Step 600: Loss = -55893.4240
# Cell 70, Step 700: Loss = -55894.2044
# Cell 70, Step 800: Loss = -55894.1480
# Cell 70, Step 900: Loss = -55892.0906
# Cell 71, Step 0: Loss = -55839.7497
# Cell 71, Step 100: Loss = -55856.8071
# Cell 71, Step 200: Loss = -55856.4970
# Cell 71, Step 300: Loss = -55857.4758
# Cell 71, Step 400: Loss = -55857.1830
# Cell 71, Step 500: Loss = -55857.9625
# Cell 71, Step 600: Loss = -55860.1132
# Cell 71, Step 700: Loss = -55856.8648
# Cell 71, Step 800: Loss = -55856.0919
# Cell 71, Step 900: Loss = -55856.3341
# Cell 72, Step 0: Loss = -55917.5543
# Cell 72, Step 100: Loss = -55915.9807
# Cell 72, Step 200: Loss = -55916.6981
# Cell 72, Step 300: Loss = -55917.6596
# Cell 72, Step 400: Loss = -55916.9676
# Cell 72, Step 500: Loss = -55914.5021
# Cell 72, Step 600: Loss = -55916.8411
# Cell 72, Step 700: Loss = -55916.8932
# Cell 72, Step 800: Loss = -55917.2066
# Cell 72, Step 900: Loss = -55917.0232
# Cell 73, Step 0: Loss = -55884.7008
# Cell 73, Step 100: Loss = -55896.6934
# Cell 73, Step 200: Loss = -55897.5123
# Cell 73, Step 300: Loss = -55896.9091
# Cell 73, Step 400: Loss = -55895.2489
# Cell 73, Step 500: Loss = -55899.3017
# Cell 73, Step 600: Loss = -55897.2135
# Cell 73, Step 700: Loss = -55895.3381
# Cell 73, Step 800: Loss = -55897.1093
# Cell 73, Step 900: Loss = -55896.3413
# Cell 74, Step 0: Loss = -55903.6363
# Cell 74, Step 100: Loss = -55916.9509
# Cell 74, Step 200: Loss = -55918.6388
# Cell 74, Step 300: Loss = -55914.0200
# Cell 74, Step 400: Loss = -55913.9631
# Cell 74, Step 500: Loss = -55914.3389
# Cell 74, Step 600: Loss = -55917.8688
# Cell 74, Step 700: Loss = -55915.3850
# Cell 74, Step 800: Loss = -55917.1189
# Cell 74, Step 900: Loss = -55916.5934
# Cell 75, Step 0: Loss = -55932.4852
# Cell 75, Step 100: Loss = -55957.3799
# Cell 75, Step 200: Loss = -55960.1323
# Cell 75, Step 300: Loss = -55960.2852
# Cell 75, Step 400: Loss = -55961.6247
# Cell 75, Step 500: Loss = -55962.4331
# Cell 75, Step 600: Loss = -55959.7582
# Cell 75, Step 700: Loss = -55961.8004
# Cell 75, Step 800: Loss = -55960.7793
# Cell 75, Step 900: Loss = -55961.9749
# Cell 76, Step 0: Loss = -55844.1366
# Cell 76, Step 100: Loss = -55845.7360
# Cell 76, Step 200: Loss = -55844.4710
# Cell 76, Step 300: Loss = -55845.3378
# Cell 76, Step 400: Loss = -55843.5200
# Cell 76, Step 500: Loss = -55845.0623
# Cell 76, Step 600: Loss = -55847.3591
# Cell 76, Step 700: Loss = -55844.9596
# Cell 76, Step 800: Loss = -55843.5141
# Cell 76, Step 900: Loss = -55843.2579
# Cell 77, Step 0: Loss = -55851.3445
# Cell 77, Step 100: Loss = -55861.2135
# Cell 77, Step 200: Loss = -55861.8885
# Cell 77, Step 300: Loss = -55860.6281
# Cell 77, Step 400: Loss = -55860.7277
# Cell 77, Step 500: Loss = -55861.0093
# Cell 77, Step 600: Loss = -55860.3665
# Cell 77, Step 700: Loss = -55860.0155
# Cell 77, Step 800: Loss = -55860.8091
# Cell 77, Step 900: Loss = -55860.5687
# Cell 78, Step 0: Loss = -55911.6542
# Cell 78, Step 100: Loss = -55930.4945
# Cell 78, Step 200: Loss = -55930.2776
# Cell 78, Step 300: Loss = -55932.9115
# Cell 78, Step 400: Loss = -55932.2312
# Cell 78, Step 500: Loss = -55928.0121
# Cell 78, Step 600: Loss = -55931.9837
# Cell 78, Step 700: Loss = -55933.0587
# Cell 78, Step 800: Loss = -55931.4944
# Cell 78, Step 900: Loss = -55933.4509
# Cell 79, Step 0: Loss = -55908.3396
# Cell 79, Step 100: Loss = -55915.9478
# Cell 79, Step 200: Loss = -55919.6593
# Cell 79, Step 300: Loss = -55917.0202
# Cell 79, Step 400: Loss = -55920.0562
# Cell 79, Step 500: Loss = -55917.0031
# Cell 79, Step 600: Loss = -55919.9246
# Cell 79, Step 700: Loss = -55916.2586
# Cell 79, Step 800: Loss = -55920.2037
# Cell 79, Step 900: Loss = -55917.9978
# Cell 80, Step 0: Loss = -55976.4851
# Cell 80, Step 100: Loss = -55995.1482
# Cell 80, Step 200: Loss = -55994.5001
# Cell 80, Step 300: Loss = -55998.6977
# Cell 80, Step 400: Loss = -55996.6194
# Cell 80, Step 500: Loss = -55992.5164
# Cell 80, Step 600: Loss = -55996.9398
# Cell 80, Step 700: Loss = -55997.4088
# Cell 80, Step 800: Loss = -55996.3006
# Cell 80, Step 900: Loss = -55998.6304
# Cell 81, Step 0: Loss = -55840.5234
# Cell 81, Step 100: Loss = -55855.7409
# Cell 81, Step 200: Loss = -55862.6617
# Cell 81, Step 300: Loss = -55862.2930
# Cell 81, Step 400: Loss = -55863.3610
# Cell 81, Step 500: Loss = -55862.3344
# Cell 81, Step 600: Loss = -55867.4258
# Cell 81, Step 700: Loss = -55863.4226
# Cell 81, Step 800: Loss = -55862.3936
# Cell 81, Step 900: Loss = -55863.4068
# Cell 82, Step 0: Loss = -55820.6330
# Cell 82, Step 100: Loss = -55845.7629
# Cell 82, Step 200: Loss = -55847.3759
# Cell 82, Step 300: Loss = -55849.7348
# Cell 82, Step 400: Loss = -55847.5766
# Cell 82, Step 500: Loss = -55849.6396
# Cell 82, Step 600: Loss = -55846.2434
# Cell 82, Step 700: Loss = -55848.4727
# Cell 82, Step 800: Loss = -55848.1867
# Cell 82, Step 900: Loss = -55846.5111
# Cell 83, Step 0: Loss = -55837.3436
# Cell 83, Step 100: Loss = -55848.5102
# Cell 83, Step 200: Loss = -55846.5109
# Cell 83, Step 300: Loss = -55847.6195
# Cell 83, Step 400: Loss = -55847.7275
# Cell 83, Step 500: Loss = -55847.5385
# Cell 83, Step 600: Loss = -55846.8467
# Cell 83, Step 700: Loss = -55849.5026
# Cell 83, Step 800: Loss = -55848.2005
# Cell 83, Step 900: Loss = -55846.3622
# Cell 84, Step 0: Loss = -56018.7819
# Cell 84, Step 100: Loss = -56032.2719
# Cell 84, Step 200: Loss = -56038.4226
# Cell 84, Step 300: Loss = -56036.0566
# Cell 84, Step 400: Loss = -56036.2763
# Cell 84, Step 500: Loss = -56036.4632
# Cell 84, Step 600: Loss = -56035.1833
# Cell 84, Step 700: Loss = -56037.5357
# Cell 84, Step 800: Loss = -56036.3624
# Cell 84, Step 900: Loss = -56035.2945
# Cell 85, Step 0: Loss = -55920.3919
# Cell 85, Step 100: Loss = -55939.4532
# Cell 85, Step 200: Loss = -55938.0638
# Cell 85, Step 300: Loss = -55938.6165
# Cell 85, Step 400: Loss = -55938.2969
# Cell 85, Step 500: Loss = -55940.3531
# Cell 85, Step 600: Loss = -55936.1367
# Cell 85, Step 700: Loss = -55939.3133
# Cell 85, Step 800: Loss = -55940.2332
# Cell 85, Step 900: Loss = -55937.6646
# Cell 86, Step 0: Loss = -55931.6927
# Cell 86, Step 100: Loss = -55958.7918
# Cell 86, Step 200: Loss = -55952.1669
# Cell 86, Step 300: Loss = -55960.0350
# Cell 86, Step 400: Loss = -55955.2383
# Cell 86, Step 500: Loss = -55958.3357
# Cell 86, Step 600: Loss = -55959.1559
# Cell 86, Step 700: Loss = -55958.6012
# Cell 86, Step 800: Loss = -55958.5894
# Cell 86, Step 900: Loss = -55958.6897
# Cell 87, Step 0: Loss = -55914.8917
# Cell 87, Step 100: Loss = -55920.5151
# Cell 87, Step 200: Loss = -55921.9802
# Cell 87, Step 300: Loss = -55919.0854
# Cell 87, Step 400: Loss = -55919.3764
# Cell 87, Step 500: Loss = -55920.1395
# Cell 87, Step 600: Loss = -55921.0759
# Cell 87, Step 700: Loss = -55921.6597
# Cell 87, Step 800: Loss = -55917.2545
# Cell 87, Step 900: Loss = -55923.2321
# Cell 88, Step 0: Loss = -55805.8151
# Cell 88, Step 100: Loss = -55851.5074
# Cell 88, Step 200: Loss = -55862.7060
# Cell 88, Step 300: Loss = -55862.1294
# Cell 88, Step 400: Loss = -55860.3307
# Cell 88, Step 500: Loss = -55863.1087
# Cell 88, Step 600: Loss = -55861.8456
# Cell 88, Step 700: Loss = -55861.5670
# Cell 88, Step 800: Loss = -55864.7805
# Cell 88, Step 900: Loss = -55860.4805
# Cell 89, Step 0: Loss = -55776.4657
# Cell 89, Step 100: Loss = -55851.7657
# Cell 89, Step 200: Loss = -55852.1675
# Cell 89, Step 300: Loss = -55854.7047
# Cell 89, Step 400: Loss = -55852.9255
# Cell 89, Step 500: Loss = -55854.5210
# Cell 89, Step 600: Loss = -55849.7189
# Cell 89, Step 700: Loss = -55851.9735
# Cell 89, Step 800: Loss = -55851.0486
# Cell 89, Step 900: Loss = -55853.4049
# Cell 90, Step 0: Loss = -55906.3703
# Cell 90, Step 100: Loss = -55918.6544
# Cell 90, Step 200: Loss = -55919.7239
# Cell 90, Step 300: Loss = -55917.6883
# Cell 90, Step 400: Loss = -55917.4445
# Cell 90, Step 500: Loss = -55918.1794
# Cell 90, Step 600: Loss = -55919.8291
# Cell 90, Step 700: Loss = -55917.4929
# Cell 90, Step 800: Loss = -55918.9426
# Cell 90, Step 900: Loss = -55918.9428
# Cell 91, Step 0: Loss = -55861.4187
# Cell 91, Step 100: Loss = -55872.2931
# Cell 91, Step 200: Loss = -55872.5561
# Cell 91, Step 300: Loss = -55872.7579
# Cell 91, Step 400: Loss = -55874.2832
# Cell 91, Step 500: Loss = -55873.5970
# Cell 91, Step 600: Loss = -55872.8728
# Cell 91, Step 700: Loss = -55873.4614
# Cell 91, Step 800: Loss = -55874.3165
# Cell 91, Step 900: Loss = -55873.9458
# Cell 92, Step 0: Loss = -55921.5079
# Cell 92, Step 100: Loss = -55932.6747
# Cell 92, Step 200: Loss = -55932.5503
# Cell 92, Step 300: Loss = -55935.0771
# Cell 92, Step 400: Loss = -55933.1383
# Cell 92, Step 500: Loss = -55931.3096
# Cell 92, Step 600: Loss = -55933.5363
# Cell 92, Step 700: Loss = -55933.4827
# Cell 92, Step 800: Loss = -55932.1995
# Cell 92, Step 900: Loss = -55931.4642
# Cell 93, Step 0: Loss = -55773.8350
# Cell 93, Step 100: Loss = -55786.3973
# Cell 93, Step 200: Loss = -55784.5475
# Cell 93, Step 300: Loss = -55785.0343
# Cell 93, Step 400: Loss = -55786.9049
# Cell 93, Step 500: Loss = -55784.8733
# Cell 93, Step 600: Loss = -55785.0574
# Cell 93, Step 700: Loss = -55784.3112
# Cell 93, Step 800: Loss = -55786.6185
# Cell 93, Step 900: Loss = -55785.1940
# Cell 94, Step 0: Loss = -56007.0228
# Cell 94, Step 100: Loss = -56009.6881
# Cell 94, Step 200: Loss = -56012.2915
# Cell 94, Step 300: Loss = -56011.9111
# Cell 94, Step 400: Loss = -56013.4670
# Cell 94, Step 500: Loss = -56008.0626
# Cell 94, Step 600: Loss = -56015.8374
# Cell 94, Step 700: Loss = -56012.5736
# Cell 94, Step 800: Loss = -56012.0107
# Cell 94, Step 900: Loss = -56012.7092
# Cell 95, Step 0: Loss = -55959.1724
# Cell 95, Step 100: Loss = -56016.8880
# Cell 95, Step 200: Loss = -56020.2301
# Cell 95, Step 300: Loss = -56019.6155
# Cell 95, Step 400: Loss = -56020.0804
# Cell 95, Step 500: Loss = -56017.7326
# Cell 95, Step 600: Loss = -56020.8992
# Cell 95, Step 700: Loss = -56018.0997
# Cell 95, Step 800: Loss = -56016.7131
# Cell 95, Step 900: Loss = -56020.6575
# Cell 96, Step 0: Loss = -55897.4927
# Cell 96, Step 100: Loss = -55935.9529
# Cell 96, Step 200: Loss = -55955.5479
# Cell 96, Step 300: Loss = -55971.3590
# Cell 96, Step 400: Loss = -55970.8017
# Cell 96, Step 500: Loss = -55973.2980
# Cell 96, Step 600: Loss = -55973.2423
# Cell 96, Step 700: Loss = -55968.7164
# Cell 96, Step 800: Loss = -55965.8315
# Cell 96, Step 900: Loss = -55970.8852
# Cell 97, Step 0: Loss = -55821.9436
# Cell 97, Step 100: Loss = -55844.9148
# Cell 97, Step 200: Loss = -55846.6940
# Cell 97, Step 300: Loss = -55844.9043
# Cell 97, Step 400: Loss = -55845.7831
# Cell 97, Step 500: Loss = -55847.4004
# Cell 97, Step 600: Loss = -55846.8704
# Cell 97, Step 700: Loss = -55847.4152
# Cell 97, Step 800: Loss = -55846.6339
# Cell 97, Step 900: Loss = -55848.2932
# Cell 98, Step 0: Loss = -55885.3138
# Cell 98, Step 100: Loss = -55887.4516
# Cell 98, Step 200: Loss = -55888.6288
# Cell 98, Step 300: Loss = -55890.4057
# Cell 98, Step 400: Loss = -55891.3852
# Cell 98, Step 500: Loss = -55889.8781
# Cell 98, Step 600: Loss = -55891.7048
# Cell 98, Step 700: Loss = -55891.8701
# Cell 98, Step 800: Loss = -55889.8063
# Cell 98, Step 900: Loss = -55890.9045
# Cell 99, Step 0: Loss = -55832.1044
# Cell 99, Step 100: Loss = -55846.8285
# Cell 99, Step 200: Loss = -55849.4887
# Cell 99, Step 300: Loss = -55847.9560
# Cell 99, Step 400: Loss = -55849.3397
# Cell 99, Step 500: Loss = -55850.9480
# Cell 99, Step 600: Loss = -55850.8469
# Cell 99, Step 700: Loss = -55840.8599
# Cell 99, Step 800: Loss = -55848.0230
# Cell 99, Step 900: Loss = -55851.1901
# Estimated proportions shape: (100, 20)
# Uncertainty shape: (100, 20)

# %%
# Assume ground truth P_cells_true from data
P_cells_true = data_loader['P_cells_true']
from sklearn.metrics import r2_score
r2 = r2_score(P_cells_true.flatten(), p_estimated.flatten())
print(f"R² with priors: {r2:.4f}")
# Uncertainty analysis
print("Mean uncertainty:", p_uncertainty.mean())
# Out:
# R² with priors: 0.9653
# Mean uncertainty: 0.007448166846646927
